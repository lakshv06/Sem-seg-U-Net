# %%
cd "/content/drive/My Drive/DL-ML/Helen Dataset/Models"
# Out:
# /content/drive/My Drive/DL-ML/Helen Dataset/Models

# %%
import F1_Score

# %%
gt_dir="/content/drive/My Drive/DL-ML/helen* dataset/Ground_truth"
predicted_dir="/content/drive/My Drive/DL-ML/helen* dataset/Pred_truth"
label_dir="/content/drive/My Drive/DL-ML/helen* dataset/label_names.txt"

# %%
F1_Score.print_f1_score(gt_dir,predicted_dir,label_dir)
# Out:
# 100%|██████████| 100/100 [01:11<00:00,  1.41it/s]
# {'bg': ([0], [0]), 'face': ([1], [1]), 'lb': ([2], [2]), 'rb': ([3], [3]), 'le': ([4], [4]), 're': ([5], [5]), 'nose': ([6], [6]), 'ulip': ([7], [7]), 'imouth': ([8], [8]), 'llip': ([9], [9]), 'hair': ([10], [10]), 'eyes': ([4, 5], [4, 5]), 'brows': ([2, 3], [2, 3]), 'mouth': ([7, 8, 9], [7, 8, 9]), 'overall': ([4, 5, 2, 3, 6, 7, 8, 9], [4, 5, 2, 3, 6, 7, 8, 9])}
# f1_bg=0.9583257238588416
# f1_face=0.9100377049782108
# f1_lb=0.5473372781065089
# f1_rb=0.5823880735219223
# f1_le=0.5961706745073331
# f1_re=0.6183392695020602
# f1_nose=0.8648840549306912
# f1_ulip=0.5957401148130265
# f1_imouth=0.6382009376738272
# f1_llip=0.6773450026723677
# f1_hair=0.8023145679193366
# f1_eyes=0.6164630202597584
# f1_brows=0.5799710414280466
# f1_mouth=0.7540529120923923
# f1_overall=0.766724115580698
